# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
data=pd.read_csv("Heart.csv")
data.AHD=data['AHD'].map({'Yes': 0, 'No': 1})
data.Thal=data['Thal'].map({'fixed': 1, 'normal': 2,'reversable':3})
data=data.drop(['ChestPain','Unnamed: 0'],axis=1)
data=data.dropna()
data.head()
# Out:
#    Age  Sex  RestBP  Chol  Fbs  RestECG  ...  ExAng  Oldpeak  Slope   Ca  Thal  AHD
# 0   63    1     145   233    1        2  ...      0      2.3      3  0.0   1.0    1
# 1   67    1     160   286    0        2  ...      1      1.5      2  3.0   2.0    0
# 2   67    1     120   229    0        2  ...      1      2.6      2  2.0   3.0    0
# 3   37    1     130   250    0        0  ...      0      3.5      3  0.0   2.0    1
# 4   41    0     130   204    0        2  ...      0      1.4      1  0.0   2.0    1
#
# [5 rows x 13 columns]

# %%
y=data['AHD']
x=data.drop('AHD',axis=1)
print(x.head())
print(y.head())
# Out:
#    Age  Sex  RestBP  Chol  Fbs  ...  ExAng  Oldpeak  Slope   Ca  Thal
# 0   63    1     145   233    1  ...      0      2.3      3  0.0   1.0
# 1   67    1     160   286    0  ...      1      1.5      2  3.0   2.0
# 2   67    1     120   229    0  ...      1      2.6      2  2.0   3.0
# 3   37    1     130   250    0  ...      0      3.5      3  0.0   2.0
# 4   41    0     130   204    0  ...      0      1.4      1  0.0   2.0
#
# [5 rows x 12 columns]
# 0    1
# 1    0
# 2    0
# 3    1
# 4    1
# Name: AHD, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

scaler=StandardScaler()
scale=scaler.fit(x_train)
x_train=scale.transform(x_train)
x_test=scale.transform(x_test)

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
pred=model.predict(x_test)

# %%
score=accuracy_score(y_test,pred)
score
# Out:
# 0.8333333333333334

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[18,  6],
#        [ 4, 32]])
